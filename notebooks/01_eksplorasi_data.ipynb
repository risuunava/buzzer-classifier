# %% [markdown]
# # Eksplorasi Data Awal
# Cek hasil OCR & struktur data sebelum feature engineering.

# %%
import pandas as pd
import sys
sys.path.append('..')

comments = pd.read_csv('../data/interim/comments_structured.csv')
profiles = pd.read_csv('../data/interim/profiles_structured.csv')
comments.head()

# %%
comments.info()
profiles.info()
